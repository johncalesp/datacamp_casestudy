# %% [markdown]
# # <div align="center">PREDICTIVE MODEL FOR BMW USED CAR SALE </div>
# ###  <div align="center">May 19, 2020 </div>
# <img src="https://www.bmw.com.pe/content/dam/bmw/common/fastlane/usedcars/premium-selection/premium-selection-image-standard-slide-01.jpg" width="800" height="400" alt="logo">

# %% [markdown]
# # Table of contents
# 1. [PROJECT MOTIVATION](#project_motivation)
# 2. [THE DATASET](#the_dataset)
# 3. [ANALYSIS PLAN](#analysis_plan)
# 4. [PERFORMANCE METRICS](#performance_metrics)
# 5. [EXPLORATORY DATA ANALYSIS](#eda)
# 6. [EXPLORATORY DATA ANALYSIS SUMMARY](#eda_summary)
# 7. [MODEL DEVELOPMENT](#model)
# 8. [CONCLUSIONS AND RECOMMENDATIONS](#conclusions)
# 9. [REFERENCES](#references)

# %% [markdown]
# ## 1. PROJECT MOTIVATION <a name="project_motivation"></a>

# %% [markdown]
# <p>The used car market is important and relevant even after the COVID-19 impact when most countries imposed lockdowns and people commute less. The estimated value in 2020 was of USD 250 billion, and it is expected to growth to USD 403 billions by 2026 with a projected 10% CAGR (1).
#
# Nowadays with the advancements in technology and digitalization of processes the automobile industry can benefit from analytical studies made in the field and the different tools available to streamline tasks involving the exploration of massive datasets using cloud computing and big data.
#
# End customers can also take advantage of these new analytical tools. Being able to accurately and objectively set a price for your own personal vehicles can help everyday user when selling their cars on online platforms. They can get a reference price tag using an API where they insert their car’s characteristic and the machine learning model will respond with a price.
#
# The main objective of this project is to provide a regression model using an appropriate library. I will explore the different features of the dataset and how they relate to the target variable, generate the model and evaluate its performance.</p>

# %% [markdown]
# ## 2. THE DATASET <a name="the_dataset"></a>
# The dataset was obtained from [Datacamp-careerhub-data repository](https://github.com/datacamp/careerhub-data)

# %% [markdown]
# ### 2.1 Data Description
# The dataset includes 8 input variables and 1 continuous target variable.

# %% [markdown]
# **<div align="center"> Table 1. Features</div>**
# <div align="center">
# <table style="border: 1px solid black; text-align:center">
#   <tr style="border: 1px solid black; text-align:center">
#     <th style="border: 1px solid black; text-align:center">Attribute</th>
#     <th style="border: 1px solid black; text-align:center">Description</th>
#     <th style="border: 1px solid black; text-align:center">Type</th>
#   </tr>
#   <tr style="border: 1px solid black; text-align:center">
#     <td style="border: 1px solid black; text-align:center">Model</td>
#     <td style="border: 1px solid black; text-align:center">Car Model</td>
#     <td style="border: 1px solid black; text-align:center">Object</td>
#   </tr>
#   <tr style="border: 1px solid black; text-align:center">
#     <td style="border: 1px solid black; text-align:center">Year</td>
#     <td style="border: 1px solid black; text-align:center">Year of manufacture</td>
#     <td style="border: 1px solid black; text-align:center">Numerical</td>
#   </tr>
#     <tr style="border: 1px solid black; text-align:center">
#     <td style="border: 1px solid black; text-align:center">Transmission</td>
#     <td style="border: 1px solid black; text-align:center">Transmission type</td>
#     <td style="border: 1px solid black; text-align:center">Object</td>
#   </tr>
#     <tr style="border: 1px solid black; text-align:center">
#     <td style="border: 1px solid black; text-align:center">Mileage</td>
#     <td style="border: 1px solid black; text-align:center">Accumulated mileage</td>
#     <td style="border: 1px solid black; text-align:center">Numerical</td>
#   </tr>
#     <tr style="border: 1px solid black; text-align:center">
#     <td style="border: 1px solid black; text-align:center">FuelType</td>
#     <td style="border: 1px solid black; text-align:center">Fuel type used</td>
#     <td style="border: 1px solid black; text-align:center">Object</td>
#   </tr>
#   <tr style="border: 1px solid black; text-align:center">
#     <td style="border: 1px solid black; text-align:center">Tax</td>
#     <td style="border: 1px solid black; text-align:center">Tax on the vehicle</td>
#     <td style="border: 1px solid black; text-align:center">Numerical</td>
#   </tr>
#   <tr style="border: 1px solid black; text-align:center">
#     <td style="border: 1px solid black; text-align:center">MPG</td>
#     <td style="border: 1px solid black; text-align:center">Miles per galon</td>
#     <td style="border: 1px solid black; text-align:center">Numerical</td>
#   </tr>
#   <tr style="border: 1px solid black; text-align:center">
#     <td style="border: 1px solid black; text-align:center">EngineSize</td>
#     <td style="border: 1px solid black; text-align:center">Engine size</td>
#     <td style="border: 1px solid black; text-align:center">Numerical</td>
#   </tr>
# </table>
# </div>

# %% [markdown]
# **<div align="center"> Table 2. Features</div>**
# <div align="center">
# <table style="border: 1px solid black; text-align:center">
#   <tr style="border: 1px solid black; text-align:center">
#     <th style="border: 1px solid black; text-align:center">Attribute</th>
#     <th style="border: 1px solid black; text-align:center">Description</th>
#     <th style="border: 1px solid black; text-align:center">Type</th>
#   </tr>
#   <tr style="border: 1px solid black; text-align:center">
#     <td style="border: 1px solid black; text-align:center">Price</td>
#     <td style="border: 1px solid black; text-align:center">Selling price</td>
#     <td style="border: 1px solid black; text-align:center">Numerical</td>
#   </tr>
# </table>

# %% [markdown]
# ## 3. Analysis Plan <a name="analysis_plan"></a>

# %% [markdown]
# The focus of this project is towards using a supervised regression solution to explore the impact of different input variables in the price of a BMW used car.
#
# The analysis will consist of the following steps:
#
# <ul>
#     <li>Defining the appropriate metrics to evaluate the solution</li>
#     <li>Perform an Exploratory Data Analysis to identify trends, associations and issues in the data</li>
#     <li>Choose an appropriate library and algorithm for the predictive model</li>
#     <li>Train, test and evaluate the model performance</li>
#     <li>Review and consider improvement opportunities</li>
# </ul>

# %% [markdown]
# ## 4. PERFORMANCE METRICS <a name="performance_metrics"></a>

# %% [markdown]
# The metrics that will be employed to evaluate the model are the following:
# <ul>
#     <li>Mean Squared Error</li>
#     <li>R2 score</li>
#     <li>Explained variance score</li>
# </ul>
#
# The mean squared error will provide us with the information on how close our model’s predictions are to the target variable. While both R2 score and explained variance score, provide an insight on how the variability in the target variable (price) is explained by the features in the model.

# %% [markdown]
# ## 5. EXPLORATORY DATA ANALYSIS <a name="eda"></a>

# %%
# Importing necessary packages for EDA
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
sns.set()

# %%
# Verifiying the dataset is uploaded correctly
os.listdir('../careerhub-data/BMW Used Car Sales')
# Out:
# ['bmw.csv', 'README.md']

# %% [markdown]
# #### Reading and checking the information of the dataset

# %%
bmw_dataset = pd.read_csv('../careerhub-data/BMW Used Car Sales/bmw.csv')

# %%
bmw_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB

# %% [markdown]
# #### All the information is present, now I verify that there are no duplicated rows

# %%
bmw_dataset.duplicated().sum()
# Out:
# 117

# %%
bmw_dataset[bmw_dataset.duplicated()].head(10)
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 174          X4  2019  33998    Semi-Auto     7272   Diesel  150  42.8
# 393          X1  2018  16995    Semi-Auto    17276   Petrol  150  46.3
# 709    2 Series  2014  11999       Manual    31289   Diesel   30  62.8
# 957    1 Series  2019  21898       Manual     4100   Petrol  150  41.5
# 1173   1 Series  2017  20995    Semi-Auto    31544   Petrol  145  39.8
# 1275         X2  2019  29770    Automatic      123   Diesel  145  48.7
# 1276         X2  2019  29770    Automatic      123   Diesel  145  48.7
# 1277         X2  2019  29770    Automatic      123   Diesel  145  48.7
# 1296         X2  2019  28608    Automatic      123   Diesel  145  50.4
# 1362         X2  2019  26972    Automatic      123   Petrol  145  38.7
#
#       engineSize
# 174          2.0
# 393          1.5
# 709          2.0
# 957          1.5
# 1173         3.0
# 1275         2.0
# 1276         2.0
# 1277         2.0
# 1296         2.0
# ...

# %%
# dropping the duplicates inplace
bmw_dataset.drop_duplicates(inplace=True)

# %%
bmw_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10664 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10664 non-null  object
#  1   year          10664 non-null  int64
#  2   price         10664 non-null  int64
#  3   transmission  10664 non-null  object
#  4   mileage       10664 non-null  int64
#  5   fuelType      10664 non-null  object
#  6   tax           10664 non-null  int64
#  7   mpg           10664 non-null  float64
#  8   engineSize    10664 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 833.1+ KB

# %% [markdown]
# #### Use describe() to check the range of numeric values

# %%
bmw_dataset.describe().T
# Out:
#               count          mean           std     min       25%      50%  \
# year        10664.0   2017.062828      2.350668  1996.0   2016.00   2017.0
# price       10664.0  22692.888691  11434.921030  1200.0  14897.00  20261.5
# mileage     10664.0  25710.978995  25146.634940     1.0   5665.75  18783.0
# tax         10664.0    131.597431     61.611394     0.0    135.00    145.0
# mpg         10664.0     56.483121     31.465604     5.5     45.60     53.3
# engineSize  10664.0      2.170161      0.552556     0.0      2.00      2.0
#
#                 75%       max
# year         2019.0    2020.0
# price       27890.0  123456.0
# mileage     38436.5  214000.0
# tax           145.0     580.0
# mpg            62.8     470.8
# engineSize      2.0       6.6

# %% [markdown]
# #### Filtering engine size equal 0

# %%
bmw_dataset['engineSize'].value_counts()
# Out:
# 2.0    6508
# 3.0    2447
# 1.5    1426
# 1.6     108
# 4.4      79
# 0.0      47
# 2.5      14
# 0.6       7
# 2.2       6
# 3.2       5
# 4.0       5
# 1.9       5
# 2.8       2
# 6.6       2
# 1.0       1
# 5.0       1
# 3.5       1
# Name: engineSize, dtype: int64

# %%
bmw_dataset[bmw_dataset['engineSize']==0][:10]
# Out:
#      model  year  price transmission  mileage fuelType  tax    mpg  engineSize
# 621     i3  2017  19998    Automatic    41949   Hybrid  140  470.8         0.0
# 778     i3  2017  19998    Automatic    41146   Hybrid    0  470.8         0.0
# 780     i3  2017  21898    Automatic    10839   Hybrid    0  470.8         0.0
# 1866    i3  2017  19980    Automatic    26965   Hybrid  140  470.8         0.0
# 2352    i3  2016  19490    Automatic     8421   Hybrid    0  470.8         0.0
# 3277    i3  2016  16482    Automatic    43695   Hybrid    0  470.8         0.0
# 3628    i3  2015  14285    Automatic    65800   Hybrid    0  470.8         0.0
# 3913    i3  2017  18500    Automatic    36429   Hybrid    0  470.8         0.0
# 4100    i3  2017  19495    Automatic    17338   Hybrid  135  470.8         0.0
# 4109    i3  2015  17481    Automatic     9886   Hybrid    0  470.8         0.0

# %%
# Filtering the rows with engineSize 0
bmw_filtered_engine = bmw_dataset[bmw_dataset['engineSize']!=0]
bmw_filtered_engine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10617 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10617 non-null  object
#  1   year          10617 non-null  int64
#  2   price         10617 non-null  int64
#  3   transmission  10617 non-null  object
#  4   mileage       10617 non-null  int64
#  5   fuelType      10617 non-null  object
#  6   tax           10617 non-null  int64
#  7   mpg           10617 non-null  float64
#  8   engineSize    10617 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 829.5+ KB

# %%
bmw_filtered_engine.describe().T
# Out:
#               count          mean           std     min      25%      50%  \
# year        10617.0   2017.067062      2.349386  1996.0   2016.0   2017.0
# price       10617.0  22711.780258  11452.884099  1200.0  14890.0  20330.0
# mileage     10617.0  25697.624847  25179.638237     1.0   5656.0  18673.0
# tax         10617.0    131.884242     61.237806     0.0    135.0    145.0
# mpg         10617.0     55.111416     20.650787     5.5     45.6     53.3
# engineSize  10617.0      2.179768      0.534534     0.6      2.0      2.0
#
#                 75%       max
# year         2019.0    2020.0
# price       27950.0  123456.0
# mileage     38480.0  214000.0
# tax           145.0     580.0
# mpg            62.8     470.8
# engineSize      2.0       6.6

# %%
bmw_filtered_engine[bmw_filtered_engine['mileage']==1]
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 2150    X2  2020  24490    Semi-Auto        1   Diesel  145  52.3         2.0

# %% [markdown]
# #### For the case where mileage is equal to 1, the year is 2020. I guess it was sell just after purchased. I will leave it because is seems like a valid record.

# %% [markdown]
# ## Visualizations of distributions

# %%
fig, ax = plt.subplots(3,2, figsize=(10,10))
ax[0,0] = sns.kdeplot(data=bmw_filtered_engine, x='year', fill=True, ax=ax[0,0])
ax[0,1] = sns.kdeplot(data=bmw_filtered_engine, x='price', log_scale=True, fill=True, ax=ax[0,1])
ax[1,0] = sns.kdeplot(data=bmw_filtered_engine, x='mileage',log_scale=True, fill=True, ax=ax[1,0])
ax[1,1] = sns.kdeplot(data=bmw_filtered_engine, x='tax',bw_adjust=2.4, fill=True, ax=ax[1,1])
ax[2,0] = sns.kdeplot(data=bmw_filtered_engine, x='mpg', fill=True, ax=ax[2,0])
ax[2,1] = sns.kdeplot(data=bmw_filtered_engine, x='engineSize',bw_adjust=2.4, fill=True, ax=ax[2,1])
plt.tight_layout()

# %% [markdown]
# #### Looks like mpg have some outlines, let's explore it with a boxplot

# %%
sns.boxplot(data=bmw_filtered_engine, y='mpg')
# Out:
# <AxesSubplot:ylabel='mpg'>

# %% [markdown]
# #### Most of the points are between 0 and 200, the outlier is over 400. Let's find out to which model it belongs

# %%
bmw_filtered_engine[bmw_filtered_engine['mpg'] > 400]
# Out:
#       model  year  price transmission  mileage  fuelType  tax    mpg  \
# 32       i3  2016  17100    Automatic    25269     Other    0  470.8
# 8188     i3  2015  14940    Automatic    59000     Other    0  470.8
# 8620     i3  2017  19300    Automatic    32867     Other    0  470.8
# 8835     i3  2015  17400    Automatic    29465  Electric    0  470.8
# 10080    i3  2017  20000    Automatic    19178     Other    0  470.8
# 10086    i3  2017  19500    Automatic    23956     Other  135  470.8
# 10325    i3  2016  17000    Automatic    41063     Other    0  470.8
# 10530    i3  2017  17600    Automatic    50867     Other  135  470.8
#
#        engineSize
# 32            0.6
# 8188          0.6
# 8620          0.6
# 8835          1.0
# 10080         0.6
# 10086         0.6
# 10325         0.6
# 10530         0.6

# %% [markdown]
# #### According to the Official site the i3 model can get 153 miles when fully charged and under ideal driving conditions. With a range extender it can get to 200 miles https://www.bmwusa.com/vehicles/bmwi/i3/sedan/overview.html#!#range-charging
#
# #### With this information, I decided to filter these rows

# %%
bmw_filtered_eng_mpg = bmw_filtered_engine[bmw_filtered_engine['mpg'] < 400]

# %% [markdown]
# #### Visualizations of distributions with filtered rows

# %%
fig, ax = plt.subplots(3,2, figsize=(10,10))
ax[0,0] = sns.kdeplot(data=bmw_filtered_eng_mpg, x='year', fill=True, ax=ax[0,0])
ax[0,0].set_xlabel('Year')
ax[0,1] = sns.kdeplot(data=bmw_filtered_eng_mpg, x='price', log_scale=True, fill=True, ax=ax[0,1])
ax[0,1].set_xlabel('Price')
ax[1,0] = sns.kdeplot(data=bmw_filtered_eng_mpg, x='mileage',log_scale=True, fill=True, ax=ax[1,0])
ax[1,0].set_xlabel('Mileage')
ax[1,1] = sns.kdeplot(data=bmw_filtered_eng_mpg, x='tax',bw_adjust=2.4, fill=True, ax=ax[1,1])
ax[1,1].set_xlabel('Tax')
ax[2,0] = sns.kdeplot(data=bmw_filtered_eng_mpg, x='mpg', fill=True, ax=ax[2,0])
ax[2,0].set_xlabel('Miles per Galon')
ax[2,1] = sns.kdeplot(data=bmw_filtered_eng_mpg, x='engineSize',bw_adjust=2.4, fill=True, ax=ax[2,1])
ax[2,1].set_xlabel('Engine Size')
plt.tight_layout()

# %%
bmw_filtered_eng_mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10609 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10609 non-null  object
#  1   year          10609 non-null  int64
#  2   price         10609 non-null  int64
#  3   transmission  10609 non-null  object
#  4   mileage       10609 non-null  int64
#  5   fuelType      10609 non-null  object
#  6   tax           10609 non-null  int64
#  7   mpg           10609 non-null  float64
#  8   engineSize    10609 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 828.8+ KB

# %%
bmw_filtered_eng_mpg.describe().T
# Out:
#               count          mean           std     min      25%      50%  \
# year        10609.0   2017.067678      2.350055  1996.0   2016.0   2017.0
# price       10609.0  22715.442643  11456.344845  1200.0  14882.0  20375.0
# mileage     10609.0  25690.453200  25185.218954     1.0   5656.0  18641.0
# tax         10609.0    131.958243     61.180485     0.0    135.0    145.0
# mpg         10609.0     54.797955     17.215222     5.5     45.6     53.3
# engineSize  10609.0      2.180922      0.533069     1.5      2.0      2.0
#
#                 75%       max
# year         2019.0    2020.0
# price       27950.0  123456.0
# mileage     38478.0  214000.0
# tax           145.0     580.0
# mpg            62.8     188.3
# engineSize      2.0       6.6

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(7,7))
bmw_filtered_eng_mpg_corr = bmw_filtered_eng_mpg.corr()
mask = np.triu(np.ones_like(bmw_filtered_eng_mpg_corr, dtype=bool))
sns.heatmap(bmw_filtered_eng_mpg_corr, mask=mask, cbar=False, cmap="BuGn", linewidths=0.3)
plt.show()

# %% [markdown]
# #### Price is more correlated with engine size, taxes, and year

# %%
plt.figure(figsize=(7,7))
ax = sns.regplot(data=bmw_filtered_eng_mpg, y='price', x='engineSize',marker="+", x_estimator=np.mean, ci=None, color="teal" )
ax.set_title('Relationship between Price and Engine size', fontsize=15)
ax.set_ylabel('Price (Pounds)', fontsize=15)
ax.set_xlabel('Engine size (cc)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(7,7))
ax = sns.regplot(data=bmw_filtered_eng_mpg, y='price', x='tax', x_estimator=np.mean, ci=None)
ax.set_title('Relationship between Price and Taxes', fontsize=15)
ax.set_ylabel('Price (Pounds)', fontsize=15)
ax.set_xlabel('Taxes (Pounds)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(7,7))
ax = sns.barplot(data=bmw_filtered_eng_mpg, y='price', x='year', palette="Blues_d")
ax.tick_params(axis='x', labelrotation = 90)
ax.set_title('Relationship between Price and Year', fontsize=15)
ax.set_ylabel('Price (Pounds)', fontsize=15)
ax.set_xlabel('Year', fontsize=15)
plt.show()

# %% [markdown]
# #### Plotting Price variation with fuel and transmission type

# %%
plt.figure(figsize=(7,7))
ax = sns.boxplot(data=bmw_filtered_eng_mpg, y='price', x='fuelType')
ax.set_title('Price by Fuel Type', fontsize=15)
ax.set_ylabel('Price (Pounds)', fontsize=15)
ax.set_xlabel('Fuel Type', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(7,7))
ax = sns.boxplot(data=bmw_filtered_eng_mpg, y='price', x='transmission')
ax.set_title('Price by Transmission type', fontsize=15)
ax.set_ylabel('Price (Pounds)', fontsize=15)
ax.set_xlabel('Transmission type', fontsize=15)
plt.show()

# %% [markdown]
# #### The price is higher for hybrid cars and semi-automatic

# %% [markdown]
# #### Grouping by car model

# %%
car_model = bmw_filtered_eng_mpg.groupby('model').agg({'price':np.mean, 'tax': np.mean}).reset_index()

# %%
car_model
# Out:
#         model         price         tax
# 0    1 Series  15818.347982  108.932039
# 1    2 Series  19453.094435  127.559022
# 2    3 Series  19854.739095  123.440329
# 3    4 Series  22441.975659  132.829615
# 4    5 Series  22496.283539  126.274976
# 5    6 Series  24354.370370  180.601852
# 6    7 Series  36934.320755  161.792453
# 7    8 Series  63997.794872  145.897436
# 8          M2  43140.333333  151.428571
# 9          M3  30740.538462  316.153846
# 10         M4  43277.303279  183.770492
# 11         M5  57760.000000  260.517241
# 12         M6  32190.000000  508.125000
# 13         X1  19835.963614  134.466750
# 14         X2  28526.808429  145.708812
# 15         X3  27742.525455  153.209091
# 16         X4  32630.740113  155.649718
# 17         X5  39558.632829  168.002160
# 18         X6  43838.613208  181.179245
# 19         X7  69842.763636  145.727273
# 20         Z3   5826.428571  280.000000
# 21         Z4  26919.242991  174.859813
# ...

# %%
# Calculating mean price and tax
mean_price = car_model['price'].mean()
mean_tax = car_model['tax'].mean()

# %%
car_model.sort_values(['price'],ascending=False, inplace=True)
plt.figure(figsize=(7,7))
ax = sns.barplot(data=car_model, y='model', x='price' , palette='summer')
ax.set_title('Price by car model', fontsize=15)
ax.set_ylabel('Model', fontsize=12)
ax.set_xlabel('Price (Pounds)', fontsize=12)
ax.axvline(x = mean_price, color='black', linestyle='--')
ax.annotate('  Average Price', xy =(mean_price+20,15),
             xytext =(mean_price+50,15) )
plt.show()

# %%
car_model.sort_values('tax',ascending=False, inplace=True)
plt.figure(figsize=(7,7))
ax = sns.barplot(data=car_model, y='model', x='tax' , palette='summer')
ax.set_title('Tax by car model', fontsize=15)
ax.set_ylabel('Model', fontsize=12)
ax.set_xlabel('Tax (Pounds)', fontsize=12)
ax.axvline(x = mean_tax, color='black', linestyle='--')
ax.annotate('  Average Tax', xy =(mean_tax+5,15),
             xytext =(mean_tax+5,15) )
plt.show()

# %% [markdown]
# ## 6. EXPLORATORY DATA ANALYSIS SUMMARY <a name="eda_summary"></a>

# %% [markdown]
# * Most of the cars were produced between 2010 and 2020, with the sales price between 10000 and 100000 following a similar trend to their milage
# * Taxes are between 100 and 200 pounds
# * Average mgp is 54
# * Common engine sizes are around 2 and 3 cc
# * Price is more correlated with engine size, taxes, and year
# * The price is higher for hybrid cars and semi-automatic
# * Usually the cars with higher sale price pay lower taxes

# %% [markdown]
# ## 7. MODEL DEVELOPMENT <a name="model"></a>

# %%
import catboost as cb
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score
import os
sns.set()

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %% [markdown]
# I will use the library CatBoost. I have been using this package for some of my projects. It is based on gradient boosting similar to XGboost and provides a more friendly support for categorical data

# %% [markdown]
# #### Preparing the data in features and target value

# %%
X_df = bmw_filtered_eng_mpg.drop("price", axis=1)
X_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10609 entries, 0 to 10780
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10609 non-null  object
#  1   year          10609 non-null  int64
#  2   transmission  10609 non-null  object
#  3   mileage       10609 non-null  int64
#  4   fuelType      10609 non-null  object
#  5   tax           10609 non-null  int64
#  6   mpg           10609 non-null  float64
#  7   engineSize    10609 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1004.0+ KB

# %%
y = bmw_filtered_eng_mpg["price"]
y[:5]
# Out:
# 0    11200
# 1    27000
# 2    16000
# 3    12750
# 4    14500
# Name: price, dtype: int64

# %% [markdown]
# #### Selecting the categorical features

# %%
cat_features = [0,2,4] # the categorical features are Model, Transmission and Fuel type

# %%
X_train, X_test, y_train, y_test = train_test_split(X_df, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# #### Generating an input format for the model using the "Pool" class

# %%
train_dataset = cb.Pool(X_train, y_train, cat_features = cat_features ) 
test_dataset = cb.Pool(X_test, y_test, cat_features = cat_features )

# %%
#Best parameters :
# iterations : 500
# lr: 0.15
#depth: 8
# l2_leaf_reg: 0.2

#Hyperparameter tunning commented after finding the best parameters. 
#Training took around 1 hour.

#model_grid = cb.CatBoostRegressor(loss_function='RMSE', logging_level='Silent')
#grid = {'iterations': [400,500,600,700],
#        'learning_rate': [0.10, 0.15, 0.25],
#        'depth': [6,8,10],
#        'l2_leaf_reg': [0.2, 0.4, 0.6]}
#model_grid.grid_search(grid, train_dataset, verbose=False)
#model_grid.score(X_test, y_test)

# %% [markdown]
# #### Generating a model using the best hyperparameters

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.2, random_state = 42)

# %%
train_dataset = cb.Pool(X_train, y_train, cat_features = cat_features ) 
valid_dataset = cb.Pool(X_valid, y_valid, cat_features = cat_features ) 
test_dataset = cb.Pool(X_test, y_test, cat_features = cat_features )

# %%
model_set_param = cb.CatBoostRegressor(loss_function='RMSE', iterations= 500,
        learning_rate= 0.15,
        depth= 8,
        l2_leaf_reg= 0.2,
        logging_level='Silent')

# %%
model_set_param.fit(train_dataset, eval_set=valid_dataset, 
                    #plot=True used to visualize the RMSE during training  
                    )

# %% [markdown]
# #### Train and Eval dataset RMSE progress
# <img src="https://github.com/johncalesp/datacamp_casestudy/blob/main/featurePlots/train_test.jpg?raw=true" width="700" height="400" alt="logo">

# %%
model_set_param.score(X_test, y_test)
# Out:
# 0.963402499870763

# %%
pred = model_set_param.predict(X_test)
rmse = (np.sqrt(mean_squared_error(y_test, pred)))
r2 = r2_score(y_test, pred)
explained_variance = explained_variance_score(y_test, pred)
print('Testing performance')
print('RMSE: {:.2f}'.format(rmse))
print('R2: {:.2f}'.format(r2))
print('Explained Variance Score: {:.2f}'.format(explained_variance))
# Out:
# Testing performance
# RMSE: 2240.49
# R2: 0.96
# Explained Variance Score: 0.96

# %%
model_set_param.get_feature_importance(prettified=True)
# Out:
#      Feature Id  Importances
# 0          year    19.866812
# 1           mpg    17.857473
# 2         model    16.568705
# 3    engineSize    16.300448
# 4       mileage    16.179926
# 5      fuelType     6.636136
# 6  transmission     4.632400
# 7           tax     1.958099

# %% [markdown]
# #### Plotting Features Importance

# %%
plt.figure(figsize=(12, 6));
ax = sns.barplot(x="Importances", y="Feature Id", data=model_set_param.get_feature_importance(prettified=True));
ax.set_title('CatBoost features importance:', fontsize=16);
ax.set_xlabel('Importance', fontsize=14);
ax.set_ylabel('Feature', fontsize=14);
plt.show()

# %% [markdown]
# #### Reviewing features importance using Shap values

# %%
import shap
explainer = shap.TreeExplainer(model_set_param)
shap_values = explainer.shap_values(train_dataset) 
shap.summary_plot(shap_values, X_train)

# %% [markdown]
# #### The model presents a 96% explaintability for the price and predicts it's value with a +/- 2240.49 (pounds) precision

# %%
# The command is used to plot the following images during execution
#features_statistics = model_set_param.calc_feature_statistics(X_df,
#                                    y,
#                                    feature = ['year', 'mileage','mpg','engineSize','tax'],
#                                    plot=True)

# %% [markdown]
# ## 8. CONCLUSIONS AND RECOMMENDATIONS <a name="conclusions"></a>

# %% [markdown]
# #### <div align="center">Year</div>
# <img src="https://github.com/johncalesp/datacamp_casestudy/blob/main/featurePlots/year.png?raw=true" width="980" height="400" alt="logo">

# %% [markdown]
# ## 9. REFERENCES <a name="references"></a>
